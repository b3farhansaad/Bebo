# %%
# نشر الموقع على Vercel

هذا الدفتر يشرح خطوات تحضير المشروع للنشر على Vercel، بناء التطبيق، ونشره للحصول على رابط مباشر.
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 1. تحضير المشروع وملفات النشر

- تأكد من وجود `index.html` في جذر المشروع.
- إذا كان المشروع يستخدم React/Vite، تأكد من وجود `package.json` و `vite.config.ts` و `tsconfig.json`.
- للتطبيق الثابت، يكفي وجود `index.html` و ملفات CSS و JS اللازمة.
</VSCode.Cell>
<VSCode.Cell language="python">
# تحقق من وجود الملفات الضرورية في المشروع
import os
root = '/workspaces/Bebo'
for filename in ['index.html', 'package.json', 'vite.config.ts', 'tsconfig.json']:
    print(filename, 'FOUND' if os.path.exists(os.path.join(root, filename)) else 'MISSING')
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 2. تثبيت Vercel CLI وتهيئة الحساب

- استخدم `npm install -g vercel` لتثبيت CLI.
- بعد التثبيت، سجل الدخول باستخدام `vercel login`.
- إذا كنت تستخدم حسابًا موجودًا، اتبع التعليمات لإكمال المصادقة.
</VSCode.Cell>
<VSCode.Cell language="python">
# في حال كان هناك إمكانية تنفيذ أوامر شل، يمكن استخدام نموذج الأمر التالي:
commands = [
    'npm install -g vercel',
    'vercel login'
]
for cmd in commands:
    print('Run:', cmd)

</VSCode.Cell>
<VSCode.Cell language="markdown">
## 3. بناء المشروع

- إذا كان لديك تطبيق Vite/React، شغل `npm run build`.
- إذا كان هو تطبيق ثابت، فيمكن نشره مباشرة بدون خطوة بناء إضافية.
</VSCode.Cell>
<VSCode.Cell language="python">
# عرض أوامر البناء المتوقعة
print('npm run build')

</VSCode.Cell>
<VSCode.Cell language="markdown">
## 4. نشر المشروع على Vercel

- استخدم الأمر `vercel` داخل مجلد المشروع.
- إذا كان المشروع مرتكزًا على React/Vite، سيطلب منك إعدادات البناء ووجهة نشر.
- اختر `yes` للمجلد الحالي و `yes` للنشر إلى `main` أو الفرع الحالي.
</VSCode.Cell>
<VSCode.Cell language="python">
print('vercel')
print('vercel --prod')

</VSCode.Cell>
<VSCode.Cell language="markdown">
## 5. الحصول على رابط النشر ومشاركته

- بعد اكتمال النشر، Vercel يعرض رابط الموقع النهائي.
- انسخ الرابط وأرسله للمستخدم.
- يمكنك أيضًا استخدام `vercel --prod --confirm` لنشر مباشر بدون أسئلة تفاعلية إذا كانت الإعدادات مستقرة.
</VSCode.Cell>
<VSCode.Cell language="python">
print('Example final link: https://your-project-name.vercel.app')
